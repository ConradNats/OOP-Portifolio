# %%
def calculate_fine(days_late,rate):
    return days_late*rate

fine = calculate_fine(3,1000)
print(fine)
# Out:
# 3000

# %%
def add(a, b):
    return a + b

result = add(5,3)

cost = result * 20000
print(cost)
# Out:
# 160000
